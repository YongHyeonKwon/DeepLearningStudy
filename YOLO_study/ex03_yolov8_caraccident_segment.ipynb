# %%
# gpu
# 드라이브 연동
# 경로 이동 study 폴더까지

# %%
# !pip install ultralytics

# %%
# 모델 불러오기
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nGXWvJrHVpxXjwU5B6qs")
project = rf.workspace("none-n1imd").project("car-jxbzt")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.207, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to car-1 in yolov8:: 100%|██████████| 671/671 [00:00<00:00, 4476.80it/s]

# %%
# 훈련시키기
# Train the model
results = model.train(data='./car-1/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
best_model = YOLO('./runs/segment/train2/weights/best.pt')
source = './car-1/valid/images/01a4cd33a4314ecf6b916d860c71ba443d1c13c4_jpg.rf.c77f19795ce0c24ca1929dbb2475bedb.jpg'
result = best_model(source, save = True, conf =0.15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0fc775d54ac2> in <cell line: 1>()
# ----> 1 best_model = YOLO('./runs/segment/train2/weights/best.pt')
#       2 source = './car-1/valid/images/01a4cd33a4314ecf6b916d860c71ba443d1c13c4_jpg.rf.c77f19795ce0c24ca1929dbb2475bedb.jpg'
#       3 result = best_model(source, save = True, conf =0.15)
#
# NameError: name 'YOLO' is not defined
